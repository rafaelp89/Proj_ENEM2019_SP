# %%
import numpy as np
import pandas as pd

# %%
enem_sp = pd.read_csv('/content/drive/MyDrive/Cursos UDEMY/Curso Estatistica com Python/arquivos1/enem_2019_tratado.csv', sep=',', encoding='iso-8859-1')
enem_sp
# Out:
#        NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE SEXO  TP_ESTADO_CIVIL  \
# 0          1,90E+11            Santa Isabel     22    M                1
# 1          1,90E+11               São Paulo     17    F                1
# 2          1,90E+11   São Bernardo do Campo     19    M                1
# 3          1,90E+11              Embu-Guaçu     17    F                1
# 4          1,90E+11               Guarulhos     23    F                1
# ...             ...                     ...    ...  ...              ...
# 499935     1,90E+11               São Paulo     18    F                1
# 499936     1,90E+11               São Paulo     17    F                1
# 499937     1,90E+11               São Paulo     17    F                1
# 499938     1,90E+11               São Paulo     17    M                1
# 499939     1,90E+11                  Araras     18    F                1
#
#           RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  \
# ...

# %% [markdown]
# # Média das notas das variáveis
# usamos a função round() para arredondar os valores usando 1 casa decimal após a virgula

# %%
#Média de idade dos participantes: 20.6
round(enem_sp['IDADE'].mean(), 1)
# Out:
# np.float64(20.6)

# %%
#Média da nota da redação: 593
round(enem_sp['NOTA_REDACAO'].mean(), 1)
# Out:
# np.float64(593.0)

# %%
#média da nota de matemática: 497,6
round(enem_sp['NOTA_MT'].mean(), 1)
# Out:
# np.float64(497.6)

# %%
#média nota de Ciencias da Natureza: 449,9
round(enem_sp['NOTA_CN'].mean(), 1)
# Out:
# np.float64(449.9)

# %%
#média nota de Ciencias Humanas: 482,2
round(enem_sp['NOTA_CH'].mean(), 1)
# Out:
# np.float64(482.2)

# %%
#média nota de Linguagens e códigos: 491,9
round(enem_sp['NOTA_LC'].mean(), 1)
# Out:
# np.float64(491.9)

# %% [markdown]
# # Mediana das notas das variáveis

# %%
#Mediana de idade dos participantes: 18
enem_sp['IDADE'].median()
# Out:
# 18.0

# %%
#mediana da nota da redação: 600
enem_sp['NOTA_REDACAO'].median()
# Out:
# 600.0

# %%
#mediana da nota de matemática: 511,8
enem_sp['NOTA_MT'].median()
# Out:
# 511.8

# %%
#mediana nota de Ciencias da Natureza: 478,1
enem_sp['NOTA_CN'].median()
# Out:
# 478.1

# %%
#mediana nota de Ciencias Humanas: 523,7
enem_sp['NOTA_CH'].median()
# Out:
# 523.7

# %%
#mediana nota de Linguagens e códigos: 538,3
enem_sp['NOTA_LC'].median()
# Out:
# 538.3

# %% [markdown]
# # Moda das variaveis
# (são os valores que mais ocorrem)

# %%
#moda de idade dos participantes: 17
enem_sp['IDADE'].mode()
# Out:
# 0    17
# Name: IDADE, dtype: int64

# %%
#moda de idade dos participantes: 600
enem_sp['NOTA_REDACAO'].mode()
# Out:
# 0    600.0
# Name: NOTA_REDACAO, dtype: float64

# %%
#moda de matematica dos participantes: 433.8
enem_sp['NOTA_MT'].mode()
# Out:
# 0    433.8
# Name: NOTA_MT, dtype: float64

# %%
#moda de ciencias da natureza dos participantes: 481.8
enem_sp['NOTA_CN'].mode()
# Out:
# 0    481.8
# Name: NOTA_CN, dtype: float64

# %%
#moda de cincias humanas dos participantes: 0
enem_sp['NOTA_CH'].mode()
# Out:
# 0    0.0
# Name: NOTA_CH, dtype: float64

# %%
#moda de linguagens e codigos dos participantes: 55.2
enem_sp['NOTA_LC'].mode()
# Out:
# 0    55.2
# Name: NOTA_LC, dtype: float64

# %% [markdown]
# # Distribuição dos dados

# %%
enem_sp.COMP3.mode()
# Out:
# 0    120.0
# Name: COMP3, dtype: float64

# %%
enem_sp.COMP3.mean()
# Out:
# np.float64(118.76069128295396)

# %%
enem_sp.COMP3.median()
# Out:
# 120.0

# %%
import plotly.express as px

# %%
grafico = px.histogram(enem_sp, x='COMP3', nbins=15)
grafico.update_layout(width=400,height=400,title_text='Notas do componente 3 da redação - Enem SP 2019')
grafico.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
enem_sp.COMP2.mode()
# Out:
# 0    120.0
# Name: COMP2, dtype: float64

# %%
enem_sp.COMP2.mean()
# Out:
# np.float64(127.06680801696204)

# %%
enem_sp.COMP2.median()
# Out:
# 120.0

# %%
grafico = px.histogram(enem_sp, x='COMP2', nbins=15)
grafico.update_layout(width=400,height=400,title_text='Notas do componente 2 da redação - Enem SP 2019')
grafico.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
