# %%
import pandas as pd
import numpy as np

# %%
enem_sp = pd.read_csv('/content/drive/MyDrive/Cursos UDEMY/Curso Estatistica com Python/arquivos1/enem_2019_tratado.csv', sep=',', encoding='iso-8859-1')
enem_sp.head(3)
# Out:
#   NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE SEXO  TP_ESTADO_CIVIL   RACA  \
# 0     1,90E+11            Santa Isabel     22    M                1  parda
# 1     1,90E+11               São Paulo     17    F                1  parda
# 2     1,90E+11   São Bernardo do Campo     19    M                1  parda
#
#    TP_NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  ... NOTA_MT  \
# 0                 1                1  não_respondeu         NaN  ...   600.2
# 1                 1                2        privada  15567761.0  ...   731.8
# 2                 1                2        pública  35904958.0  ...   393.2
#
#    TP_LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  COMP5  \
# 0     Inglês                1.0  160.0  200.0  180.0  200.0  200.0
# 1     Inglês                1.0  160.0  120.0  200.0  200.0  200.0
# 2   Espanhol                1.0   80.0  160.0  120.0  100.0  100.0
#
#    NOTA_REDACAO INTERNET
# 0         940.0      Sim
# 1         880.0      Não
# ...

# %% [markdown]
# # Medidas de dispersão

# %%
#variância
enem_sp['NOTA_MT'].var()
# Out:
# 33659.47050441108

# %%
#desvio padão
enem_sp['NOTA_MT'].std()
# Out:
# 183.46517518158885

# %%
#média
enem_sp['NOTA_MT'].mean()
# Out:
# np.float64(497.5942403088371)

# %%
# desvio absoluto
enem_sp['NOTA_MT'].abs().mean()
# Out:
# np.float64(497.5942403088371)

# %%
#descrição geral para algumas variáveis
enem_sp[['NOTA_MT', 'NOTA_REDACAO', 'NOTA_CN',	'NOTA_CH',	'NOTA_LC']].describe()
# Out:
#              NOTA_MT   NOTA_REDACAO        NOTA_CN        NOTA_CH  \
# count  499940.000000  499940.000000  499940.000000  499940.000000
# mean      497.594240     593.018322     449.917000     482.228054
# std       183.465175     170.536724     152.982255     161.122963
# min         0.000000       0.000000       0.000000       0.000000
# 25%       427.900000     500.000000     412.400000     450.600000
# 50%       511.800000     600.000000     478.100000     523.700000
# 75%       617.900000     680.000000     544.400000     578.100000
# max       984.700000    1000.000000     860.900000     822.700000
#
#              NOTA_LC
# count  499940.000000
# mean      491.941262
# std       156.247134
# min         0.000000
# 25%       490.100000
# 50%       538.300000
# 75%       576.200000
# max       772.300000

# %% [markdown]
# # medidas de posição

# %%
#mínimo (menor nota em matematica)
enem_sp['NOTA_MT'].min()
# Out:
# 0.0

# %%
#maximo (maior nota em matematica)
enem_sp['NOTA_MT'].max()
# Out:
# 984.7

# %%
#primeiro quartil
enem_sp['NOTA_MT'].quantile(q=0.25)
# Out:
# np.float64(427.9)

# %%
#terceiro quartil
enem_sp['NOTA_MT'].quantile(q=0.75)
# Out:
# np.float64(617.9)

# %%
#mediana ou segundo quartil
enem_sp['NOTA_MT'].median()
# Out:
# 511.8

# %%
#resumo geral
enem_sp[['NOTA_MT', 'NOTA_REDACAO', 'NOTA_CN',	'NOTA_CH',	'NOTA_LC']].describe()
# Out:
#              NOTA_MT   NOTA_REDACAO        NOTA_CN        NOTA_CH  \
# count  499940.000000  499940.000000  499940.000000  499940.000000
# mean      497.594240     593.018322     449.917000     482.228054
# std       183.465175     170.536724     152.982255     161.122963
# min         0.000000       0.000000       0.000000       0.000000
# 25%       427.900000     500.000000     412.400000     450.600000
# 50%       511.800000     600.000000     478.100000     523.700000
# 75%       617.900000     680.000000     544.400000     578.100000
# max       984.700000    1000.000000     860.900000     822.700000
#
#              NOTA_LC
# count  499940.000000
# mean      491.941262
# std       156.247134
# min         0.000000
# 25%       490.100000
# 50%       538.300000
# 75%       576.200000
# max       772.300000

# %% [markdown]
# # Gráfico box Plot e análise de Outliers

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Matplotlib

# %%
plt.boxplot(enem_sp['NOTA_MT'])
plt.show()

# %% [markdown]
# Seaborn

# %%
import seaborn as sns

# %%
sns.boxplot(data=enem_sp['NOTA_MT'])
# Out:
# <Axes: ylabel='NOTA_MT'>

# %% [markdown]
# Plotly

# %%
import plotly.express as px

# %%
grafico = px.box(enem_sp, y=['NOTA_MT'])
grafico.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Tratamento de Outliers:

# %%
sem_outliers = enem_sp.loc[enem_sp['NOTA_MT'] <= 902.9]
sem_outliers = sem_outliers.loc[sem_outliers['NOTA_MT'] >= 359.1]

# %%
sem_outliers.head()
# Out:
#   NU_INSCRICAO NO_MUNICIPIO_RESIDENCIA  IDADE SEXO  TP_ESTADO_CIVIL    RACA  \
# 0     1,90E+11            Santa Isabel     22    M                1   parda
# 1     1,90E+11               São Paulo     17    F                1   parda
# 2     1,90E+11   São Bernardo do Campo     19    M                1   parda
# 3     1,90E+11              Embu-Guaçu     17    F                1   parda
# 4     1,90E+11               Guarulhos     23    F                1  branca
#
#    TP_NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA   CO_ESCOLA  ... NOTA_MT  \
# 0                 1                1  não_respondeu         NaN  ...   600.2
# 1                 1                2        privada  15567761.0  ...   731.8
# 2                 1                2        pública  35904958.0  ...   393.2
# 3                 1                2        pública         NaN  ...   419.2
# 4                 1                1  não_respondeu         NaN  ...   796.1
#
# ...

# %% [markdown]
# Outliers tratados

# %%
grafico = px.box(sem_outliers, y='NOTA_MT')
grafico.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#analisando tipo de escola em relação a nota de matemática
grafico = px.box(enem_sp, x='ESCOLA', y='NOTA_MT')
grafico.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
